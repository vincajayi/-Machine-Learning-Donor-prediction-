# %% [markdown]
# # Machine Learning: Donor prediction

# %% [markdown]
# # Introduction

# %% [markdown]
# There is no doubt that accurate prediction of the donor behaviours will increase the charity organisation revenue and enable the company to make decisions on how to allocate resources as well as predicting future growth. In contrast, poor revenue forecasting will increase company production cost and reduce company efficiency.
# In this project, we compare the forecasting performance of six different Artificial Intelligence techniques together.  We aim to choose the most appropriate method to estimate cost and predict profit.
#
# In particular, we considered the following classification techniques: Logistic Regression, KneigborsClassifier, GaussianNB,  RandomForestClassifier, Linear Discriminant Analysis and Neural Network Classifier (NN). The results show that DecisionTressClasifier outperforms other selected techniques. When the favoured model is applied to estimate cost, evidence reveals that if the charity sends postcards to only those households that are likely to donate, it will spend £ 1946 and earn £4200, to generate a profit of £2254.

# %%
Here’s an overview of the steps we’ll take in this article:
    
1.Importing the libraries
2.Loading the dataset
3.Data Exploration 
4.Data Preparation
5.Feature selection
6.Visualization of the variables
7.Evaluating the machine learning algorithm
8.Evaluating the dataset features

# %% [markdown]
# # Step 1. Libraries importation

# %% [markdown]
# The first step, as always, is to import the required libraries. Execute the following code to do so:

# %%
# Modules needed
import sys
# scipy # for statistics
import scipy
# numpy for array, matrix and vector calculations
import numpy as np
# matplotlib for graphs
import pandas as pd
# scikit-learn for machine learning
import sklearn

# Load  specialised libraries
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
# model selection
from sklearn import model_selection
from sklearn.model_selection import GridSearchCV
# kpi: evaulating the performance of the model
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import fbeta_score
# the stars of the show: the models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# # Step 2: Loading the Dataset

# %% [markdown]
# The second step is to load the dataset from the local CSV file into your Python program. Let’s use the read_csv method of the pandas library. Execute the following code:

# %%
dataset = pd.read_csv(r'C:\Users\Ajay\Desktop\NoteMachine\Donor Raw Data_ML with Python.csv')

# %% [markdown]
# # Step 3: Data Exploration

# %% [markdown]
# The third, we check for the missing values, numbers of rows, colunms and the number of the objects in the dataset.
# From the dataset, we have 17372 rows, 50 colunms. We also noticed that the follwoing variables have missing values: TARGET_D, DONOR_AGE, INCOME_GROUP, WEALTH RATING and MONTHS_SINCE_LAST_PROM_RESP

# %%
dataset.head()
# Out:
#    TARGET_B  TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  \
# 0         0       NaN               5                  101       87.0
# 1         1      10.0              12                  137       79.0
# 2         0       NaN              37                  113       75.0
# 3         0       NaN              38                   92        NaN
# 4         0       NaN              41                  101       74.0
#
#    IN_HOUSE URBANICITY SES CLUSTER_CODE HOME_OWNER       ...        \
# 0         0          ?   ?            .          H       ...
# 1         0          R   2           45          H       ...
# 2         0          S   1           11          H       ...
# 3         0          U   2            4          H       ...
# 4         0          R   2           49          U       ...
#
#   LIFETIME_GIFT_RANGE  LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  \
# 0                15.0                   20.0                    5.0
# 1                20.0                   25.0                    5.0
# 2                23.0                   28.0                    5.0
# 3                14.0                   17.0                    3.0
# 4                20.0                   25.0                    5.0
#
#   LAST_GIFT_AMT  CARD_PROM_12  NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  \
# 0          15.0             5              12                      26
# 1          17.0             7              21                       7
# 2          19.0            11              32                       6
# 3          15.0            11              33                       6
# 4          25.0             6              19                      18
#
#    MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  FILE_CARD_GIFT
# 0                       92           8.49               7
# 1                      122          14.72              12
# 2                      105          16.75              16
# 3                       92          11.76              12
# 4                       92           8.83               3
#
# [5 rows x 50 columns]

# %%
dataset.shape
# this imply, I have a  dataset of 19372 rows and that there are 50 columns
# Out:
# (19372, 50)

# %%
# bottom 10 records
dataset.tail(10)
# Out:
#        TARGET_B  TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  \
# 19362         1      10.0          191663                   65       70.0
# 19363         0       NaN          191671                  137       68.0
# 19364         0       NaN          191672                  137       84.0
# 19365         0       NaN          191673                  137       64.0
# 19366         0       NaN          191679                  137       85.0
# 19367         0       NaN          191687                   89       66.0
# 19368         0       NaN          191710                  137       77.0
# 19369         0       NaN          191746                   29        NaN
# 19370         0       NaN          191775                  129       78.0
# 19371         1     150.0          191779                   29       70.0
#
#        IN_HOUSE URBANICITY SES CLUSTER_CODE HOME_OWNER       ...        \
# 19362         1          S   1           14          U       ...
# 19363         1          R   2           44          U       ...
# 19364         0          C   3           31          U       ...
# 19365         1          C   1           23          U       ...
# 19366         1          T   2           40          U       ...
# 19367         1          U   1            3          H       ...
# 19368         1          C   1           24          H       ...
# 19369         1          S   1           11          U       ...
# 19370         1          ?   ?            .          U       ...
# 19371         0          ?   ?            .          U       ...
#
#       LIFETIME_GIFT_RANGE  LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  \
# 19362                 7.0                   12.0                    5.0
# 19363                15.0                   20.0                    5.0
# 19364                 7.0                   10.0                    3.0
# 19365                31.0                   36.0                    5.0
# 19366                 7.0                   10.0                    3.0
# 19367                22.0                   25.0                    3.0
# 19368                 9.0                   10.0                    1.0
# 19369                 0.0                   15.0                   15.0
# 19370                20.0                   25.0                    5.0
# 19371                 0.0                   25.0                   25.0
#
#       LAST_GIFT_AMT  CARD_PROM_12  NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  \
# 19362          10.0             4               8                      20
# 19363          20.0             4              11                      18
# 19364           5.0             6              15                      17
# 19365          25.0             5               9                      16
# 19366           5.0             5              12                      15
# 19367          15.0             6              13                      18
# 19368          10.0             6              13                      21
# 19369          15.0             3               9                      23
# 19370          25.0             7              24                       8
# 19371          25.0             4               9                      24
#
#        MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  FILE_CARD_GIFT
# 19362                       63           9.31               8
# 19363                      129          12.13               7
# 19364                      122           6.91               7
# 19365                      121          16.50               7
# 19366                      126           5.32              13
# 19367                       81          17.17               3
# 19368                      130           7.81              13
# 19369                       23          15.00               0
# 19370                      129          18.33              11
# 19371                       24          25.00               1
#
# [10 rows x 50 columns]

# %%
# to check the row
dataset.iloc[2]
# Out:
# TARGET_B                           0
# TARGET_D                         NaN
# CONTROL_NUMBER                    37
# MONTHS_SINCE_ORIGIN              113
# DONOR_AGE                         75
# IN_HOUSE                           0
# URBANICITY                         S
# SES                                1
# CLUSTER_CODE                      11
# HOME_OWNER                         H
# DONOR_GENDER                       F
# INCOME_GROUP                       5
# PUBLISHED_PHONE                    0
# OVERLAY_SOURCE                     P
# MOR_HIT_RATE                       0
# WEALTH_RATING                      9
# MEDIAN_HOME_VALUE               2388
# MEDIAN_HOUSEHOLD_INCOME          405
# PCT_OWNER_OCCUPIED                63
# PER_CAPITA_INCOME              30855
# PCT_ATTRIBUTE1                     0
# PCT_ATTRIBUTE2                    25
# PCT_ATTRIBUTE3                    26
# PCT_ATTRIBUTE4                    57
# PEP_STAR                           1
# RECENT_STAR_STATUS                 1
# RECENCY_STATUS_96NK                S
# FREQUENCY_STATUS_97NK              3
# RECENT_RESPONSE_PROP           0.409
# RECENT_AVG_GIFT_AMT            21.67
# RECENT_CARD_RESPONSE_PROP      0.545
# RECENT_AVG_CARD_GIFT_AMT       22.67
# RECENT_RESPONSE_COUNT              9
# RECENT_CARD_RESPONSE_COUNT         6
# MONTHS_SINCE_LAST_PROM_RESP       14
# LIFETIME_CARD_PROM                44
# LIFETIME_PROM                    119
# LIFETIME_GIFT_AMOUNT             603
# LIFETIME_GIFT_COUNT               36
# LIFETIME_AVG_GIFT_AMT          16.75
# LIFETIME_GIFT_RANGE               23
# LIFETIME_MAX_GIFT_AMT             28
# LIFETIME_MIN_GIFT_AMT              5
# LAST_GIFT_AMT                     19
# CARD_PROM_12                      11
# NUMBER_PROM_12                    32
# MONTHS_SINCE_LAST_GIFT             6
# MONTHS_SINCE_FIRST_GIFT          105
# FILE_AVG_GIFT                  16.75
# FILE_CARD_GIFT                    16
# Name: 2, dtype: object

# %%
dataset.isnull().sum()
# Out:
# TARGET_B                           0
# TARGET_D                       14529
# CONTROL_NUMBER                     0
# MONTHS_SINCE_ORIGIN                0
# DONOR_AGE                       4795
# IN_HOUSE                           0
# URBANICITY                         0
# SES                                0
# CLUSTER_CODE                       0
# HOME_OWNER                         0
# DONOR_GENDER                       0
# INCOME_GROUP                    4392
# PUBLISHED_PHONE                    0
# OVERLAY_SOURCE                     0
# MOR_HIT_RATE                       0
# WEALTH_RATING                   8810
# MEDIAN_HOME_VALUE                  0
# MEDIAN_HOUSEHOLD_INCOME            0
# PCT_OWNER_OCCUPIED                 0
# PER_CAPITA_INCOME                  0
# PCT_ATTRIBUTE1                     0
# PCT_ATTRIBUTE2                     0
# PCT_ATTRIBUTE3                     0
# PCT_ATTRIBUTE4                     0
# PEP_STAR                           0
# RECENT_STAR_STATUS                 0
# RECENCY_STATUS_96NK                0
# FREQUENCY_STATUS_97NK              0
# RECENT_RESPONSE_PROP               0
# RECENT_AVG_GIFT_AMT                0
# RECENT_CARD_RESPONSE_PROP          0
# RECENT_AVG_CARD_GIFT_AMT           0
# RECENT_RESPONSE_COUNT              0
# RECENT_CARD_RESPONSE_COUNT         0
# MONTHS_SINCE_LAST_PROM_RESP      246
# LIFETIME_CARD_PROM                 0
# LIFETIME_PROM                      0
# LIFETIME_GIFT_AMOUNT               0
# LIFETIME_GIFT_COUNT                0
# LIFETIME_AVG_GIFT_AMT              0
# LIFETIME_GIFT_RANGE                0
# LIFETIME_MAX_GIFT_AMT              0
# LIFETIME_MIN_GIFT_AMT              0
# LAST_GIFT_AMT                      0
# CARD_PROM_12                       0
# NUMBER_PROM_12                     0
# MONTHS_SINCE_LAST_GIFT             0
# MONTHS_SINCE_FIRST_GIFT            0
# FILE_AVG_GIFT                      0
# FILE_CARD_GIFT                     0
# dtype: int64

# %% [markdown]
# # Step 4: Data Preparation

# %%
We check the percenatge of the missing value

# %%
 # for Target D variables = 14529/19372*100 = 75%
    # for DONOR AGE = 4795/19372*100 = 25%
    # for INCOME_GROUP = 4392/19372*100 = 23%
    # for  WEALTH RATING = 8810/19372*100 = 45%
    #  for MONTHS_SINCE_LAST_PROM_RESP  = 246/19372*100  = 1%

# %% [markdown]
#  To aviod model misspecifcation due to the lower sample, we removed the variables ( 'WEALTH RATING' and 'TARGET_D'), since percentage of missing values are more than 25% of the total samples

# %%
# Here we eliminate variable that are missing 
mis_var = ['TARGET_D', 'WEALTH_RATING']

dataset.drop(mis_var, axis = 1, inplace= True)

# %%
# the list of the variables without TARGET_D and WEALTH_RATING
dataset.head()
# Out:
#    TARGET_B  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE  \
# 0         0               5                  101       87.0         0
# 1         1              12                  137       79.0         0
# 2         0              37                  113       75.0         0
# 3         0              38                   92        NaN         0
# 4         0              41                  101       74.0         0
#
#   URBANICITY SES CLUSTER_CODE HOME_OWNER DONOR_GENDER       ...        \
# 0          ?   ?            .          H            M       ...
# 1          R   2           45          H            M       ...
# 2          S   1           11          H            F       ...
# 3          U   2            4          H            F       ...
# 4          R   2           49          U            F       ...
#
#    LIFETIME_GIFT_RANGE  LIFETIME_MAX_GIFT_AMT LIFETIME_MIN_GIFT_AMT  \
# 0                 15.0                   20.0                   5.0
# 1                 20.0                   25.0                   5.0
# 2                 23.0                   28.0                   5.0
# 3                 14.0                   17.0                   3.0
# 4                 20.0                   25.0                   5.0
#
#    LAST_GIFT_AMT  CARD_PROM_12  NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  \
# 0           15.0             5              12                      26
# 1           17.0             7              21                       7
# 2           19.0            11              32                       6
# 3           15.0            11              33                       6
# 4           25.0             6              19                      18
#
#    MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  FILE_CARD_GIFT
# 0                       92           8.49               7
# 1                      122          14.72              12
# 2                      105          16.75              16
# 3                       92          11.76              12
# 4                       92           8.83               3
#
# [5 rows x 48 columns]

# %%
# We identies the list of other categories variables

cat_var = ['IN_HOUSE', 'INCOME_GROUP', 'PUBLISHED_PHONE', 'PEP_STAR',  'RECENT_STAR_STATUS','FREQUENCY_STATUS_97NK', 
           'RECENT_CARD_RESPONSE_COUNT','URBANICITY', 'SES', 'CLUSTER_CODE',
           'HOME_OWNER', 'DONOR_GENDER', 'OVERLAY_SOURCE', 'RECENCY_STATUS_96NK']

# %%
data = dataset[cat_var]
print(data.tail())
# Out:
#        IN_HOUSE  INCOME_GROUP  PUBLISHED_PHONE  PEP_STAR  RECENT_STAR_STATUS  \
# 19367         1           4.0                1         0                   0
# 19368         1           5.0                1         1                   1
# 19369         1           1.0                1         0                   0
# 19370         1           6.0                1         1                  14
# 19371         0           5.0                1         0                   0
#
#        FREQUENCY_STATUS_97NK  RECENT_CARD_RESPONSE_COUNT URBANICITY SES  \
# 19367                      2                           1          U   1
# 19368                      3                           2          C   1
# 19369                      1                           0          S   1
# 19370                      1                           0          ?   ?
# 19371                      1                           1          ?   ?
#
#       CLUSTER_CODE HOME_OWNER DONOR_GENDER OVERLAY_SOURCE RECENCY_STATUS_96NK
# 19367            3          H            F              B                   A
# 19368           24          H            F              B                   S
# 19369           11          U            M              P                   N
# 19370            .          U            M              B                   A
# 19371            .          U            M              B                   N

# %%
data = dataset[cat_var]
print(data.head())
# Out:
#    IN_HOUSE  INCOME_GROUP  PUBLISHED_PHONE  PEP_STAR  RECENT_STAR_STATUS  \
# 0         0           2.0                0         1                   0
# 1         0           7.0                0         1                   1
# 2         0           5.0                0         1                   1
# 3         0           6.0                1         1                   0
# 4         0           2.0                1         0                   0
#
#    FREQUENCY_STATUS_97NK  RECENT_CARD_RESPONSE_COUNT URBANICITY SES  \
# 0                      1                           0          ?   ?
# 1                      2                           2          R   2
# 2                      3                           6          S   1
# 3                      3                           4          U   2
# 4                      1                           1          R   2
#
#   CLUSTER_CODE HOME_OWNER DONOR_GENDER OVERLAY_SOURCE RECENCY_STATUS_96NK
# 0            .          H            M              P                   A
# 1           45          H            M              P                   S
# 2           11          H            F              P                   S
# 3            4          H            F              B                   A
# 4           49          U            F              B                   A

# %%
# Here we eliminate the following variables because most of thier categories are more than two. 
# Our priminary analysis indcates that inclusion of more than two variables do not improve the accuracy of our prediction.
 # Note that not excluding these variables may cause dummy variable trap caused by including a dummy variable for every single category.
del_var = ['URBANICITY','SES','RECENCY_STATUS_96NK','OVERLAY_SOURCE', 'DONOR_GENDER']

dataset.drop(del_var, axis = 1, inplace= True)

# %%
# MODEFICATION OF HOME_OWBER INTO AN INTEGERS
dataset['HOME_OWNER'].replace('H',2,inplace = True)
dataset['HOME_OWNER'].replace('U',1,inplace = True)

# %%
# To view the remaining data
print(dataset.tail(5))
# Out:
#        TARGET_B  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE  \
# 19367         0          191687                   89       66.0         1
# 19368         0          191710                  137       77.0         1
# 19369         0          191746                   29        NaN         1
# 19370         0          191775                  129       78.0         1
# 19371         1          191779                   29       70.0         0
#
#       CLUSTER_CODE  HOME_OWNER  INCOME_GROUP  PUBLISHED_PHONE  MOR_HIT_RATE  \
# 19367            3           2           4.0                1           241
# 19368           24           2           5.0                1           240
# 19369           11           1           1.0                1             0
# 19370            .           1           6.0                1             0
# 19371            .           1           5.0                1             2
#
#             ...        LIFETIME_GIFT_RANGE  LIFETIME_MAX_GIFT_AMT  \
# 19367       ...                       22.0                   25.0
# 19368       ...                        9.0                   10.0
# 19369       ...                        0.0                   15.0
# 19370       ...                       20.0                   25.0
# 19371       ...                        0.0                   25.0
#
#        LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  NUMBER_PROM_12  \
# 19367                    3.0           15.0             6              13
# 19368                    1.0           10.0             6              13
# 19369                   15.0           15.0             3               9
# 19370                    5.0           25.0             7              24
# 19371                   25.0           25.0             4               9
#
#        MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  \
# 19367                      18                       81          17.17
# 19368                      21                      130           7.81
# 19369                      23                       23          15.00
# 19370                       8                      129          18.33
# 19371                      24                       24          25.00
#
#        FILE_CARD_GIFT
# 19367               3
# 19368              13
# 19369               0
# 19370              11
# 19371               1
#
# [5 rows x 43 columns]

# %%
# for other missing  values, we calculate the mean values 

mean_age = dataset['DONOR_AGE'].mean()
mean_months_since = dataset['MONTHS_SINCE_LAST_PROM_RESP'].mean()
mean_income_group = dataset['INCOME_GROUP'].mean()

# %%
# We replaced the missing value with thier means

dataset['DONOR_AGE'].fillna(mean_age, inplace = True)
dataset['MONTHS_SINCE_LAST_PROM_RESP'].fillna(mean_months_since, inplace = True)
dataset['INCOME_GROUP'].fillna(mean_income_group, inplace = True)

# %%
# we view the data again the the misssing value have been replaced
print(dataset.head(10))
# Out:
#    TARGET_B  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE  \
# 0         0               5                  101  87.000000         0
# 1         1              12                  137  79.000000         0
# 2         0              37                  113  75.000000         0
# 3         0              38                   92  58.919051         0
# 4         0              41                  101  74.000000         0
# 5         0              52                  101  63.000000         0
# 6         0              53                   89  71.000000         0
# 7         1              67                   89  79.000000         0
# 8         0              70                   89  41.000000         0
# 9         1              71                  101  63.000000         0
#
#   CLUSTER_CODE  HOME_OWNER  INCOME_GROUP  PUBLISHED_PHONE  MOR_HIT_RATE  \
# 0            .           2           2.0                0             0
# 1           45           2           7.0                0             0
# 2           11           2           5.0                0             0
# 3            4           2           6.0                1             0
# 4           49           1           2.0                1             8
# 5            8           1           3.0                0             0
# 6           50           2           5.0                0             0
# 7           28           2           1.0                0             0
# 8           30           2           4.0                0             0
# 9           43           2           4.0                1             0
#
#         ...        LIFETIME_GIFT_RANGE  LIFETIME_MAX_GIFT_AMT  \
# 0       ...                       15.0                   20.0
# 1       ...                       20.0                   25.0
# 2       ...                       23.0                   28.0
# 3       ...                       14.0                   17.0
# 4       ...                       20.0                   25.0
# 5       ...                        7.0                   10.0
# 6       ...                       15.0                   20.0
# 7       ...                        4.0                    7.0
# 8       ...                        4.0                    7.0
# 9       ...                        8.0                   11.0
#
#    LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  NUMBER_PROM_12  \
# 0                    5.0           15.0             5              12
# 1                    5.0           17.0             7              21
# 2                    5.0           19.0            11              32
# 3                    3.0           15.0            11              33
# 4                    5.0           25.0             6              19
# 5                    3.0           10.0             9              20
# 6                    5.0           20.0             7              18
# 7                    3.0            5.0             9              24
# 8                    3.0            5.0            11              25
# 9                    3.0            8.0            11              27
#
#    MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  \
# 0                      26                       92           8.49
# 1                       7                      122          14.72
# 2                       6                      105          16.75
# 3                       6                       92          11.76
# 4                      18                       92           8.83
# 5                      19                       91           5.82
# 6                      21                       91          11.00
# 7                       9                       91           5.05
# 8                      17                       91           5.03
# 9                       9                       91           6.82
#
#    FILE_CARD_GIFT
# 0               7
# 1              12
# 2              16
# 3              12
# 4               3
# 5               6
# 6               8
# 7               8
# 8              14
# 9              13
#
# [10 rows x 43 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19372 entries, 0 to 19371
# Data columns (total 43 columns):
# TARGET_B                       19372 non-null int64
# CONTROL_NUMBER                 19372 non-null int64
# MONTHS_SINCE_ORIGIN            19372 non-null int64
# DONOR_AGE                      19372 non-null float64
# IN_HOUSE                       19372 non-null int64
# CLUSTER_CODE                   19372 non-null object
# HOME_OWNER                     19372 non-null int64
# INCOME_GROUP                   19372 non-null float64
# PUBLISHED_PHONE                19372 non-null int64
# MOR_HIT_RATE                   19372 non-null int64
# MEDIAN_HOME_VALUE              19372 non-null int64
# MEDIAN_HOUSEHOLD_INCOME        19372 non-null int64
# PCT_OWNER_OCCUPIED             19372 non-null int64
# PER_CAPITA_INCOME              19372 non-null int64
# PCT_ATTRIBUTE1                 19372 non-null int64
# PCT_ATTRIBUTE2                 19372 non-null int64
# PCT_ATTRIBUTE3                 19372 non-null int64
# PCT_ATTRIBUTE4                 19372 non-null int64
# PEP_STAR                       19372 non-null int64
# RECENT_STAR_STATUS             19372 non-null int64
# FREQUENCY_STATUS_97NK          19372 non-null int64
# RECENT_RESPONSE_PROP           19372 non-null float64
# RECENT_AVG_GIFT_AMT            19372 non-null float64
# RECENT_CARD_RESPONSE_PROP      19372 non-null float64
# RECENT_AVG_CARD_GIFT_AMT       19372 non-null float64
# RECENT_RESPONSE_COUNT          19372 non-null int64
# RECENT_CARD_RESPONSE_COUNT     19372 non-null int64
# MONTHS_SINCE_LAST_PROM_RESP    19372 non-null float64
# LIFETIME_CARD_PROM             19372 non-null int64
# LIFETIME_PROM                  19372 non-null int64
# LIFETIME_GIFT_AMOUNT           19372 non-null float64
# LIFETIME_GIFT_COUNT            19372 non-null int64
# LIFETIME_AVG_GIFT_AMT          19372 non-null float64
# LIFETIME_GIFT_RANGE            19372 non-null float64
# LIFETIME_MAX_GIFT_AMT          19372 non-null float64
# LIFETIME_MIN_GIFT_AMT          19372 non-null float64
# LAST_GIFT_AMT                  19372 non-null float64
# CARD_PROM_12                   19372 non-null int64
# NUMBER_PROM_12                 19372 non-null int64
# MONTHS_SINCE_LAST_GIFT         19372 non-null int64
# MONTHS_SINCE_FIRST_GIFT        19372 non-null int64
# FILE_AVG_GIFT                  19372 non-null float64
# FILE_CARD_GIFT                 19372 non-null int64
# dtypes: float64(14), int64(28), object(1)
# memory usage: 6.4+ MB

# %%
# We noticed that 'CLUSTER_CODE' may contain some strings or  objects 
# To remove the object

nan_char = ["?","" ," .","-","NULL", "..."]
for char in nan_char:
    dataset = dataset.replace(char,np.nan)

# %%
#Checking whether object has been removed from the 'CLUSTER_CODE'
dataset[dataset['CLUSTER_CODE'].isnull()]
# Out:
#        TARGET_B  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE  \
# 0             0               5                  101  87.000000         0
# 15            0             156                  125  73.000000         0
# 18            0             186                  125  58.919051         0
# 24            0             257                   89  55.000000         0
# 39            0             379                   89  58.919051         0
# 43            1             403                   89  58.000000         0
# 55            0             544                   89  58.000000         0
# 62            0             583                  137  76.000000         0
# 81            0             696                  137  86.000000         0
# 128           1            1102                  137  86.000000         0
# 145           0            1329                   29  65.000000         0
# 161           0            1477                   65  58.919051         0
# 175           0            1628                   17  55.000000         0
# 183           0            1703                   29  58.919051         0
# 192           0            1794                   89  58.919051         0
# 197           0            1832                   29  58.919051         0
# 211           0            1968                  113  76.000000         0
# 224           1            2081                  113  58.919051         0
# 237           1            2194                   65  37.000000         0
# 250           1            2311                   65  58.919051         0
# 264           1            2408                  113  34.000000         0
# 270           1            2464                   77  56.000000         0
# 280           1            2512                   17  71.000000         0
# 289           1            2596                   29  58.919051         0
# 307           0            2798                   21  58.919051         0
# 312           1            2853                  137  58.919051         0
# 319           1            2935                   17  58.919051         0
# 328           0            2997                  125  69.000000         0
# 334           1            3018                   65  58.919051         1
# 337           0            3054                   29  58.919051         1
# ...         ...             ...                  ...        ...       ...
# 19327         0          191233                  101  58.919051         0
# 19329         0          191254                  101  58.919051         1
# 19330         0          191256                   17  85.000000         1
# 19331         0          191260                  137  72.000000         1
# 19332         0          191267                   77  87.000000         1
# 19333         0          191275                   41  58.919051         1
# 19334         1          191296                  113  50.000000         1
# 19335         1          191297                  137  58.919051         1
# 19336         0          191316                   53  72.000000         1
# 19337         0          191355                   77  58.919051         0
# 19338         0          191384                  101  56.000000         1
# 19339         0          191405                   89  62.000000         1
# 19340         0          191418                  113  37.000000         1
# 19341         0          191430                   41  72.000000         1
# 19343         0          191465                   29  79.000000         1
# 19344         0          191475                  137  84.000000         0
# 19345         0          191482                  101  44.000000         1
# 19346         0          191484                   65  42.000000         1
# 19347         0          191487                  137  68.000000         1
# 19348         0          191491                  113  74.000000         1
# 19349         0          191493                   29  83.000000         1
# 19351         0          191524                   53  55.000000         0
# 19352         1          191528                   53  56.000000         0
# 19353         0          191530                   65  63.000000         0
# 19354         1          191531                   41  60.000000         0
# 19355         1          191547                  101  80.000000         1
# 19356         0          191550                  101  74.000000         1
# 19358         0          191604                  113  58.919051         1
# 19370         0          191775                  129  78.000000         1
# 19371         1          191779                   29  70.000000         0
#
#       CLUSTER_CODE  HOME_OWNER  INCOME_GROUP  PUBLISHED_PHONE  MOR_HIT_RATE  \
# 0              NaN           2      2.000000                0             0
# 15             NaN           1      5.000000                0            17
# 18             NaN           1      3.907543                0             0
# 24             NaN           2      4.000000                0             0
# 39             NaN           1      3.907543                0             0
# 43             NaN           1      2.000000                0             0
# 55             NaN           1      2.000000                0             0
# 62             NaN           1      3.907543                0             0
# 81             NaN           1      3.907543                1             0
# 128            NaN           1      4.000000                0             0
# 145            NaN           1      6.000000                0             0
# 161            NaN           1      5.000000                0             0
# 175            NaN           1      1.000000                0            28
# 183            NaN           1      3.907543                0             0
# 192            NaN           1      1.000000                1             0
# 197            NaN           1      3.907543                0             0
# 211            NaN           1      3.907543                1             0
# 224            NaN           1      3.000000                1             2
# 237            NaN           2      7.000000                1             0
# 250            NaN           1      3.907543                0             0
# 264            NaN           2      7.000000                0             1
# 270            NaN           2      4.000000                0             0
# 280            NaN           2      5.000000                0             0
# 289            NaN           2      5.000000                1             0
# 307            NaN           1      3.907543                0             0
# 312            NaN           1      3.907543                0             0
# 319            NaN           2      7.000000                0             0
# 328            NaN           2      1.000000                0             0
# 334            NaN           1      3.907543                0             0
# 337            NaN           1      3.907543                0             0
# ...            ...         ...           ...              ...           ...
# 19327          NaN           1      5.000000                0             0
# 19329          NaN           1      6.000000                0             8
# 19330          NaN           1      2.000000                1             1
# 19331          NaN           1      3.000000                0             0
# 19332          NaN           1      1.000000                1             0
# 19333          NaN           1      3.907543                0             0
# 19334          NaN           1      5.000000                1            10
# 19335          NaN           1      4.000000                1             0
# 19336          NaN           1      5.000000                1             3
# 19337          NaN           1      3.907543                1             0
# 19338          NaN           1      3.907543                0             0
# 19339          NaN           1      5.000000                0            35
# 19340          NaN           1      7.000000                0            28
# 19341          NaN           1      1.000000                1             3
# 19343          NaN           1      5.000000                0             0
# 19344          NaN           1      3.907543                0             0
# 19345          NaN           1      3.000000                0             0
# 19346          NaN           1      3.000000                1             5
# 19347          NaN           1      1.000000                1             1
# 19348          NaN           1      3.907543                0             0
# 19349          NaN           1      2.000000                1            21
# 19351          NaN           1      3.907543                1             0
# 19352          NaN           1      7.000000                1             1
# 19353          NaN           1      4.000000                1             2
# 19354          NaN           1      3.907543                0             0
# 19355          NaN           1      2.000000                1             5
# 19356          NaN           1      6.000000                0             4
# 19358          NaN           1      3.907543                1             0
# 19370          NaN           1      6.000000                1             0
# 19371          NaN           1      5.000000                1             2
#
#             ...        LIFETIME_GIFT_RANGE  LIFETIME_MAX_GIFT_AMT  \
# 0           ...                       15.0                   20.0
# 15          ...                        8.0                   10.0
# 18          ...                       17.0                   20.0
# 24          ...                       17.0                   20.0
# 39          ...                       10.0                   15.0
# 43          ...                       30.0                   50.0
# 55          ...                       10.0                   15.0
# 62          ...                        8.0                   10.0
# 81          ...                        7.0                   10.0
# 128         ...                       12.0                   16.0
# 145         ...                       11.0                   16.0
# 161         ...                        6.0                   16.0
# 175         ...                       10.0                   15.0
# 183         ...                       10.0                   20.0
# 192         ...                       15.0                   20.0
# 197         ...                       23.0                   33.0
# 211         ...                       12.0                   15.0
# 224         ...                        9.0                   12.0
# 237         ...                        3.0                    6.0
# 250         ...                        7.0                   10.0
# 264         ...                       17.0                   20.0
# 270         ...                        6.0                   11.0
# 280         ...                        0.0                   25.0
# 289         ...                       15.0                   25.0
# 307         ...                        0.0                    5.0
# 312         ...                        8.0                   11.0
# 319         ...                       40.0                   50.0
# 328         ...                        8.0                    9.0
# 334         ...                       17.0                   20.0
# 337         ...                       15.0                   20.0
# ...         ...                        ...                    ...
# 19327       ...                       14.0                   24.0
# 19329       ...                        7.0                   10.0
# 19330       ...                        0.0                   25.0
# 19331       ...                       13.0                   15.0
# 19332       ...                       22.0                   25.0
# 19333       ...                        8.0                   10.0
# 19334       ...                        5.0                   10.0
# 19335       ...                        9.0                   12.0
# 19336       ...                       10.0                   20.0
# 19337       ...                        4.0                    7.0
# 19338       ...                       15.0                   25.0
# 19339       ...                        0.0                   25.0
# 19340       ...                       19.0                   22.0
# 19341       ...                       10.0                   20.0
# 19343       ...                       20.0                   25.0
# 19344       ...                       15.0                   25.0
# 19345       ...                       11.0                   16.0
# 19346       ...                        5.0                   20.0
# 19347       ...                        7.0                   12.0
# 19348       ...                       10.0                   15.0
# 19349       ...                        0.0                   15.0
# 19351       ...                       10.0                   15.0
# 19352       ...                       13.0                   16.0
# 19353       ...                        6.0                   11.0
# 19354       ...                        7.0                   12.0
# 19355       ...                       25.0                   30.0
# 19356       ...                       20.0                   25.0
# 19358       ...                        4.0                    6.0
# 19370       ...                       20.0                   25.0
# 19371       ...                        0.0                   25.0
#
#        LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  NUMBER_PROM_12  \
# 0                        5.0           15.0             5              12
# 15                       2.0           10.0             6              15
# 18                       3.0           11.0            10              28
# 24                       3.0           19.0             5              12
# 39                       5.0           15.0             6              17
# 43                      20.0           35.0             8              21
# 55                       5.0           15.0            11              26
# 62                       2.0           10.0             7              19
# 81                       3.0            7.0            10              30
# 128                      4.0           12.0            11              29
# 145                      5.0           14.0             6              17
# 161                     10.0           14.0             6              18
# 175                      5.0           15.0             2               8
# 183                     10.0           20.0             5              15
# 192                      5.0           15.0            11              25
# 197                     10.0           27.0            11              26
# 211                      3.0           15.0             7              18
# 224                      3.0            8.0             9              25
# 237                      3.0            4.0             9              21
# 250                      3.0            7.0            11              26
# 264                      3.0           11.0             7              17
# 270                      5.0            8.0            11              25
# 280                     25.0           25.0            10              24
# 289                     10.0           20.5             8              22
# 307                      5.0            5.0             5              13
# 312                      3.0           10.0             8              19
# 319                     10.0           20.0             5              28
# 328                      1.0            5.0             6              28
# 334                      3.0           19.0             7              27
# 337                      5.0           15.0            11              27
# ...                      ...            ...           ...             ...
# 19327                   10.0           24.0             6              13
# 19329                    3.0            5.0             6              14
# 19330                   25.0           25.0             5              12
# 19331                    2.0            5.0             6              13
# 19332                    3.0           18.0            11              26
# 19333                    2.0           10.0             6              13
# 19334                    5.0           10.0             6              14
# 19335                    3.0            5.0             3               5
# 19336                   10.0           20.0             6              15
# 19337                    3.0            7.0             6              14
# 19338                   10.0           15.0             6              13
# 19339                   25.0           25.0            10              25
# 19340                    3.0           22.0             6              13
# 19341                   10.0           20.0             4              11
# 19343                    5.0           25.0             6              13
# 19344                   10.0           20.0             5              10
# 19345                    5.0           16.0             6              14
# 19346                   15.0           20.0             6              13
# 19347                    5.0           12.0             6              12
# 19348                    5.0           15.0             4              11
# 19349                   15.0           15.0             3               8
# 19351                    5.0            8.0             6              17
# 19352                    3.0           16.0             6              12
# 19353                    5.0           11.0             6              13
# 19354                    5.0           12.0             6              12
# 19355                    5.0           28.0             7              16
# 19356                    5.0           15.0             9              25
# 19358                    2.0            4.0             5              12
# 19370                    5.0           25.0             7              24
# 19371                   25.0           25.0             4               9
#
#        MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  \
# 0                          26                       92           8.49
# 15                         18                      124           6.09
# 18                         15                      125           8.82
# 24                         25                       87          11.71
# 39                         18                       85           8.50
# 43                          7                       83          33.50
# 55                         18                       78           8.88
# 62                         21                      129           4.36
# 81                          5                      129           6.46
# 128                         5                      131          11.33
# 145                        17                       55          11.25
# 161                        17                       55          13.25
# 175                        15                       44          10.00
# 183                        22                       33          13.33
# 192                        17                       89          11.26
# 197                        17                       32          22.50
# 211                        17                      105          10.56
# 224                         4                      106           7.84
# 237                        12                       63           4.07
# 250                         7                       62           5.33
# 264                        18                      105           9.13
# 270                         6                       77           7.82
# 280                        16                       20          25.00
# 289                         6                       23          18.42
# 307                        15                       21           5.00
# 312                         7                      121           7.77
# 319                        10                       17          22.50
# 328                         9                      118           4.25
# 334                         5                       64          12.00
# 337                         5                       44          13.91
# ...                       ...                      ...            ...
# 19327                      18                       90          17.60
# 19329                      15                       89           7.40
# 19330                      16                       16          25.00
# 19331                      18                      120           4.95
# 19332                      18                       77          12.12
# 19333                      19                       45           6.57
# 19334                      17                      113           9.07
# 19335                      15                      126           7.75
# 19336                      18                       53          16.00
# 19337                      16                       68           5.92
# 19338                      18                       93          14.50
# 19339                       8                       80          25.00
# 19340                      17                      110           7.89
# 19341                      17                       45          15.00
# 19343                      21                       33          15.00
# 19344                      26                      126          18.64
# 19345                      18                       90          11.86
# 19346                      18                       56          18.33
# 19347                      23                      126           8.47
# 19348                      19                      104           9.56
# 19349                      23                       23          15.00
# 19351                       6                       52           9.40
# 19352                      18                       52           8.50
# 19353                      15                       65           7.38
# 19354                      15                       44           9.00
# 19355                      18                      101          21.85
# 19356                       5                       92          11.67
# 19358                      15                      110           4.09
# 19370                       8                      129          18.33
# 19371                      24                       24          25.00
#
#        FILE_CARD_GIFT
# 0                   7
# 15                 10
# 18                 23
# 24                  3
# 39                  4
# 43                  4
# 55                  7
# 62                  8
# 81                 25
# 128                16
# 145                 1
# 161                 2
# 175                 2
# 183                 3
# 192                 9
# 197                 7
# 211                 9
# 224                23
# 237                10
# 250                 6
# 264                12
# 270                14
# 280                 1
# 289                 4
# 307                 2
# 312                11
# 319                 1
# 328                13
# 334                 2
# 337                 6
# ...               ...
# 19327               2
# 19329               5
# 19330               0
# 19331              10
# 19332              11
# 19333               6
# 19334               9
# 19335              20
# 19336               2
# 19337               6
# 19338               4
# 19339               4
# 19340               6
# 19341               1
# 19343               2
# 19344               7
# 19345               3
# 19346               1
# 19347               7
# 19348               5
# 19349               1
# 19351               1
# 19352               1
# 19353               2
# 19354               3
# 19355               9
# 19356               8
# 19358              12
# 19370              11
# 19371               1
#
# [454 rows x 43 columns]

# %%
# We caculate the mode value for CLUSTER CODE and replaced the NAN with the model value

mode_cluster = dataset['CLUSTER_CODE'].mode()
print('mean',mode_cluster)
# Out:
# mean 0    40
# dtype: object

# %%
dataset['CLUSTER_CODE'].fillna(mode_cluster, inplace = True)

# %%
# We encord the object to form a numerical value

from sklearn import preprocessing
from collections import defaultdict
d = defaultdict(preprocessing.LabelEncoder)

# Encoding the categorical variable
fit = dataset.select_dtypes(include=['object']).fillna('NA').apply(lambda x: d[x.name].fit_transform(x))

#Convert the categorical columns based on encoding
for i in list(d.keys()):
    dataset[i] = d[i].transform(dataset[i].fillna('NA'))

# %%
# We view our data again, 
# We noticed that, there is no missing value, object and NAN. 
# Therefore, our data can be used for modelling.

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19372 entries, 0 to 19371
# Data columns (total 43 columns):
# TARGET_B                       19372 non-null int64
# CONTROL_NUMBER                 19372 non-null int64
# MONTHS_SINCE_ORIGIN            19372 non-null int64
# DONOR_AGE                      19372 non-null float64
# IN_HOUSE                       19372 non-null int64
# CLUSTER_CODE                   19372 non-null int64
# HOME_OWNER                     19372 non-null int64
# INCOME_GROUP                   19372 non-null float64
# PUBLISHED_PHONE                19372 non-null int64
# MOR_HIT_RATE                   19372 non-null int64
# MEDIAN_HOME_VALUE              19372 non-null int64
# MEDIAN_HOUSEHOLD_INCOME        19372 non-null int64
# PCT_OWNER_OCCUPIED             19372 non-null int64
# PER_CAPITA_INCOME              19372 non-null int64
# PCT_ATTRIBUTE1                 19372 non-null int64
# PCT_ATTRIBUTE2                 19372 non-null int64
# PCT_ATTRIBUTE3                 19372 non-null int64
# PCT_ATTRIBUTE4                 19372 non-null int64
# PEP_STAR                       19372 non-null int64
# RECENT_STAR_STATUS             19372 non-null int64
# FREQUENCY_STATUS_97NK          19372 non-null int64
# RECENT_RESPONSE_PROP           19372 non-null float64
# RECENT_AVG_GIFT_AMT            19372 non-null float64
# RECENT_CARD_RESPONSE_PROP      19372 non-null float64
# RECENT_AVG_CARD_GIFT_AMT       19372 non-null float64
# RECENT_RESPONSE_COUNT          19372 non-null int64
# RECENT_CARD_RESPONSE_COUNT     19372 non-null int64
# MONTHS_SINCE_LAST_PROM_RESP    19372 non-null float64
# LIFETIME_CARD_PROM             19372 non-null int64
# LIFETIME_PROM                  19372 non-null int64
# LIFETIME_GIFT_AMOUNT           19372 non-null float64
# LIFETIME_GIFT_COUNT            19372 non-null int64
# LIFETIME_AVG_GIFT_AMT          19372 non-null float64
# LIFETIME_GIFT_RANGE            19372 non-null float64
# LIFETIME_MAX_GIFT_AMT          19372 non-null float64
# LIFETIME_MIN_GIFT_AMT          19372 non-null float64
# LAST_GIFT_AMT                  19372 non-null float64
# CARD_PROM_12                   19372 non-null int64
# NUMBER_PROM_12                 19372 non-null int64
# MONTHS_SINCE_LAST_GIFT         19372 non-null int64
# MONTHS_SINCE_FIRST_GIFT        19372 non-null int64
# FILE_AVG_GIFT                  19372 non-null float64
# FILE_CARD_GIFT                 19372 non-null int64
# dtypes: float64(14), int64(29)
# memory usage: 6.4 MB

# %% [markdown]
# # Step 5. Feature selection

# %% [markdown]
# From above table, we have more than 40 variables.  The question is that, would all these variable be relevant for our model? our concens is that, we don't want to include irrelevant variable in building our model, because existence of the irrelevant variables will exagerate the result. In this case,the training model will be inconsistence and less precise. To identify irrelevant variables and select important variables for the predictive model, the following tests are considered for variable selection.
#
# 1. Weight of evidence (WOE) and Information value (IV)
# 2. Random Forest
# 3. Recursive Feature Elimination
# 4. Chi Square test
# 5. Linear Support Vector Classificatio
# 6. Extratrees Classifier
#
#
#
# Note that, we combined all these tests because each of the test has advantage and disadvantage

# %%
# we identify the lebel variable and other features

array = dataset.values

# features/ variables
features = array[:,1:] # : all rows , all columns from the seconds

# target B : donation or not
# Y needs to be one column only
labels = array[:,0] # : all rows , first column

# %% [markdown]
# # Feature selection using Weight of evidence (WOE) and Information value (IV)

# %%
# import packages
import pandas as pd
import numpy as np
import pandas.core.algorithms as algos
from pandas import Series
import scipy.stats.stats as stats
import re
import traceback
import string

max_bin = 20
force_bin = 3

# define a binning function
def mono_bin(Y, X, n = max_bin):
    
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]
    r = 0
    while np.abs(r) < 1:
        try:
            d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.qcut(notmiss.X, n)})
            d2 = d1.groupby('Bucket', as_index=True)
            r, p = stats.spearmanr(d2.mean().X, d2.mean().Y)
            n = n - 1 
        except Exception as e:
            n = n - 1

    if len(d2) == 1:
        n = force_bin         
        bins = algos.quantile(notmiss.X, np.linspace(0, 1, n))
        if len(np.unique(bins)) == 2:
            bins = np.insert(bins, 0, 1)
            bins[1] = bins[1]-(bins[1]/2)
        d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.cut(notmiss.X, np.unique(bins),include_lowest=True)}) 
        d2 = d1.groupby('Bucket', as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["MIN_VALUE"] = d2.min().X
    d3["MAX_VALUE"] = d2.max().X
    d3["COUNT"] = d2.count().Y
    d3["EVENT"] = d2.sum().Y
    d3["NONEVENT"] = d2.count().Y - d2.sum().Y
    d3=d3.reset_index(drop=True)
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]       
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    
    return(d3)

def char_bin(Y, X):
        
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]    
    df2 = notmiss.groupby('X',as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["COUNT"] = df2.count().Y
    d3["MIN_VALUE"] = df2.sum().Y.index
    d3["MAX_VALUE"] = d3["MIN_VALUE"]
    d3["EVENT"] = df2.sum().Y
    d3["NONEVENT"] = df2.count().Y - df2.sum().Y
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]      
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    d3 = d3.reset_index(drop=True)
    
    return(d3)

def data_vars(df1, target):
    
    stack = traceback.extract_stack()
    filename, lineno, function_name, code = stack[-2]
    vars_name = re.compile(r'\((.*?)\).*$').search(code).groups()[0]
    final = (re.findall(r"[\w']+", vars_name))[-1]
    
    x = df1.dtypes.index
    count = -1
    
    for i in x:
        if i.upper() not in (final.upper()):
            if np.issubdtype(df1[i], np.number) and len(Series.unique(df1[i])) > 2:
                conv = mono_bin(target, df1[i])
                conv["VAR_NAME"] = i
                count = count + 1
            else:
                conv = char_bin(target, df1[i])
                conv["VAR_NAME"] = i            
                count = count + 1
                
            if count == 0:
                iv_df = conv
            else:
                iv_df = iv_df.append(conv,ignore_index=True)
    
    iv = pd.DataFrame({'IV':iv_df.groupby('VAR_NAME').IV.max()})
    iv = iv.reset_index()
    return(iv_df,iv)

# %%
final_iv, IV = data_vars(dataset, dataset.TARGET_B)

# %%
IV = IV.rename(columns={'VAR_NAME':'index'})
IV.sort_values(['IV'],ascending=0)
# Out:
#                           index        IV
# 39        RECENT_RESPONSE_COUNT  0.090920
# 6         FREQUENCY_STATUS_97NK  0.077015
# 37   RECENT_CARD_RESPONSE_COUNT  0.076266
# 40         RECENT_RESPONSE_PROP  0.075305
# 4                 FILE_AVG_GIFT  0.068246
# 11        LIFETIME_AVG_GIFT_AMT  0.068246
# 10                LAST_GIFT_AMT  0.066563
# 5                FILE_CARD_GIFT  0.066285
# 14          LIFETIME_GIFT_COUNT  0.064998
# 36          RECENT_AVG_GIFT_AMT  0.062091
# 16        LIFETIME_MAX_GIFT_AMT  0.059889
# 32                     PEP_STAR  0.059825
# 38    RECENT_CARD_RESPONSE_PROP  0.051517
# 17        LIFETIME_MIN_GIFT_AMT  0.045360
# 22       MONTHS_SINCE_LAST_GIFT  0.032209
# 18                LIFETIME_PROM  0.025228
# 12           LIFETIME_CARD_PROM  0.023475
# 23  MONTHS_SINCE_LAST_PROM_RESP  0.022977
# 21      MONTHS_SINCE_FIRST_GIFT  0.022408
# 24          MONTHS_SINCE_ORIGIN  0.020889
# 13         LIFETIME_GIFT_AMOUNT  0.018915
# 0                  CARD_PROM_12  0.017802
# 19            MEDIAN_HOME_VALUE  0.016123
# 26               NUMBER_PROM_12  0.015472
# 15          LIFETIME_GIFT_RANGE  0.010119
# 33            PER_CAPITA_INCOME  0.009843
# 9                      IN_HOUSE  0.008373
# 20      MEDIAN_HOUSEHOLD_INCOME  0.007590
# 35     RECENT_AVG_CARD_GIFT_AMT  0.006760
# 8                  INCOME_GROUP  0.006089
# 3                     DONOR_AGE  0.005391
# 1                  CLUSTER_CODE  0.003943
# 2                CONTROL_NUMBER  0.002595
# 25                 MOR_HIT_RATE  0.002373
# 28               PCT_ATTRIBUTE2  0.001529
# 41           RECENT_STAR_STATUS  0.001104
# 7                    HOME_OWNER  0.000978
# 31           PCT_OWNER_OCCUPIED  0.000497
# 29               PCT_ATTRIBUTE3  0.000285
# 30               PCT_ATTRIBUTE4  0.000178
# 34              PUBLISHED_PHONE  0.000055
# 27               PCT_ATTRIBUTE1  0.000014

# %% [markdown]
# # Feature Selection Using Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

clf.fit(features,labels)

preds = clf.predict(features)

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(preds,labels)
print(accuracy)
# Out:
# 0.9764608713607268

# %%
# We identify both target and features
labels = dataset['TARGET_B']
features = dataset[dataset.columns.difference(['TARGET_B','URBANICITY','SES','RECENCY_STATUS_96NK','OVERLAY_SOURCE', 'DONOR_GENDER'])] 

# We include all variables whether they will still be relevant

# %%
from pandas import DataFrame
VI = DataFrame(clf.feature_importances_, columns = ["RF"], index=features.columns)

# %%
VI = VI.reset_index()
VI.sort_values(['RF'],ascending=0)
# Out:
#                           index        RF
# 0                  CARD_PROM_12  0.045926
# 12           LIFETIME_CARD_PROM  0.044663
# 9                      IN_HOUSE  0.043790
# 10                LAST_GIFT_AMT  0.040324
# 11        LIFETIME_AVG_GIFT_AMT  0.038476
# 16        LIFETIME_MAX_GIFT_AMT  0.038395
# 15          LIFETIME_GIFT_RANGE  0.035513
# 14          LIFETIME_GIFT_COUNT  0.035427
# 20      MEDIAN_HOUSEHOLD_INCOME  0.033774
# 2                CONTROL_NUMBER  0.033731
# 29               PCT_ATTRIBUTE3  0.033181
# 39        RECENT_RESPONSE_COUNT  0.032218
# 28               PCT_ATTRIBUTE2  0.031305
# 31           PCT_OWNER_OCCUPIED  0.030804
# 4                 FILE_AVG_GIFT  0.030446
# 40         RECENT_RESPONSE_PROP  0.030408
# 21      MONTHS_SINCE_FIRST_GIFT  0.028648
# 38    RECENT_CARD_RESPONSE_PROP  0.024527
# 37   RECENT_CARD_RESPONSE_COUNT  0.024194
# 27               PCT_ATTRIBUTE1  0.023876
# 35     RECENT_AVG_CARD_GIFT_AMT  0.023193
# 23  MONTHS_SINCE_LAST_PROM_RESP  0.022325
# 22       MONTHS_SINCE_LAST_GIFT  0.021378
# 6         FREQUENCY_STATUS_97NK  0.021299
# 30               PCT_ATTRIBUTE4  0.021131
# 26               NUMBER_PROM_12  0.020992
# 32                     PEP_STAR  0.020792
# 8                  INCOME_GROUP  0.019638
# 41           RECENT_STAR_STATUS  0.019572
# 33            PER_CAPITA_INCOME  0.016875
# 34              PUBLISHED_PHONE  0.014897
# 1                  CLUSTER_CODE  0.013533
# 24          MONTHS_SINCE_ORIGIN  0.012655
# 36          RECENT_AVG_GIFT_AMT  0.012600
# 25                 MOR_HIT_RATE  0.012216
# 13         LIFETIME_GIFT_AMOUNT  0.011965
# 18                LIFETIME_PROM  0.008228
# 19            MEDIAN_HOME_VALUE  0.008205
# 7                    HOME_OWNER  0.006097
# 5                FILE_CARD_GIFT  0.005557
# 17        LIFETIME_MIN_GIFT_AMT  0.005362
# 3                     DONOR_AGE  0.001863

# %% [markdown]
# # Recursive Feature Elimination using LogisticRegression

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
rfe = RFE(model, 20)
fit = rfe.fit(features, labels)

# %%
from pandas import DataFrame
Selected = DataFrame(rfe.support_, columns = ["RFE"], index=features.columns)
Selected = Selected.reset_index()

# %%
Selected[Selected['RFE'] == True]
# Out:
#                           index   RFE
# 0                  CARD_PROM_12  True
# 6         FREQUENCY_STATUS_97NK  True
# 7                    HOME_OWNER  True
# 8                  INCOME_GROUP  True
# 9                      IN_HOUSE  True
# 12           LIFETIME_CARD_PROM  True
# 14          LIFETIME_GIFT_COUNT  True
# 18                LIFETIME_PROM  True
# 21      MONTHS_SINCE_FIRST_GIFT  True
# 22       MONTHS_SINCE_LAST_GIFT  True
# 23  MONTHS_SINCE_LAST_PROM_RESP  True
# 26               NUMBER_PROM_12  True
# 32                     PEP_STAR  True
# 34              PUBLISHED_PHONE  True
# 36          RECENT_AVG_GIFT_AMT  True
# 37   RECENT_CARD_RESPONSE_COUNT  True
# 38    RECENT_CARD_RESPONSE_PROP  True
# 39        RECENT_RESPONSE_COUNT  True
# 40         RECENT_RESPONSE_PROP  True
# 41           RECENT_STAR_STATUS  True

# %% [markdown]
# # Feature importance with ExtraTreesClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier()
model.fit(features, labels)

print(model.feature_importances_)
# Out:
# [0.02139897 0.02875667 0.03088355 0.02960668 0.0241464  0.02337597
#  0.0212006  0.01688885 0.02673289 0.00514908 0.02524319 0.0245897
#  0.02553956 0.02406156 0.02468356 0.02504053 0.0224592  0.0220575
#  0.02619471 0.02915269 0.02911669 0.02589326 0.02798596 0.02661878
#  0.02272967 0.02253462 0.02526524 0.02040347 0.02885476 0.02893106
#  0.02859138 0.02820993 0.00940441 0.02861938 0.01673021 0.02231724
#  0.02323993 0.02127421 0.02403841 0.02305163 0.02700927 0.01201861]

# %%
from pandas import DataFrame
FI = DataFrame(model.feature_importances_, columns = ["Extratrees"], index=features.columns)

# %%
FI = FI.reset_index()

# %%
FI.sort_values(['Extratrees'],ascending=0)
# Out:
#                           index  Extratrees
# 2                CONTROL_NUMBER    0.030884
# 3                     DONOR_AGE    0.029607
# 19            MEDIAN_HOME_VALUE    0.029153
# 20      MEDIAN_HOUSEHOLD_INCOME    0.029117
# 29               PCT_ATTRIBUTE3    0.028931
# 28               PCT_ATTRIBUTE2    0.028855
# 1                  CLUSTER_CODE    0.028757
# 33            PER_CAPITA_INCOME    0.028619
# 30               PCT_ATTRIBUTE4    0.028591
# 31           PCT_OWNER_OCCUPIED    0.028210
# 22       MONTHS_SINCE_LAST_GIFT    0.027986
# 40         RECENT_RESPONSE_PROP    0.027009
# 8                  INCOME_GROUP    0.026733
# 23  MONTHS_SINCE_LAST_PROM_RESP    0.026619
# 18                LIFETIME_PROM    0.026195
# 21      MONTHS_SINCE_FIRST_GIFT    0.025893
# 12           LIFETIME_CARD_PROM    0.025540
# 26               NUMBER_PROM_12    0.025265
# 10                LAST_GIFT_AMT    0.025243
# 15          LIFETIME_GIFT_RANGE    0.025041
# 14          LIFETIME_GIFT_COUNT    0.024684
# 11        LIFETIME_AVG_GIFT_AMT    0.024590
# 4                 FILE_AVG_GIFT    0.024146
# 13         LIFETIME_GIFT_AMOUNT    0.024062
# 38    RECENT_CARD_RESPONSE_PROP    0.024038
# 5                FILE_CARD_GIFT    0.023376
# 36          RECENT_AVG_GIFT_AMT    0.023240
# 39        RECENT_RESPONSE_COUNT    0.023052
# 24          MONTHS_SINCE_ORIGIN    0.022730
# 25                 MOR_HIT_RATE    0.022535
# 16        LIFETIME_MAX_GIFT_AMT    0.022459
# 35     RECENT_AVG_CARD_GIFT_AMT    0.022317
# 17        LIFETIME_MIN_GIFT_AMT    0.022058
# 0                  CARD_PROM_12    0.021399
# 37   RECENT_CARD_RESPONSE_COUNT    0.021274
# 6         FREQUENCY_STATUS_97NK    0.021201
# 27               PCT_ATTRIBUTE1    0.020403
# 7                    HOME_OWNER    0.016889
# 34              PUBLISHED_PHONE    0.016730
# 41           RECENT_STAR_STATUS    0.012019
# 32                     PEP_STAR    0.009404
# 9                      IN_HOUSE    0.005149

# %% [markdown]
# # Feature selection using  Chi Sequre

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

model = SelectKBest(score_func=chi2, k=5)
fit = model.fit(features.abs(), labels)

# %%
from pandas import DataFrame
pd.options.display.float_format = '{:.2f}'.format
chi_sq = DataFrame(fit.scores_, columns = ["Chi_Square"], index=features.columns)

# %%
chi_sq = chi_sq.reset_index()

# %%
chi_sq.sort_values('Chi_Square',ascending=0)
# Out:
#                           index  Chi_Square
# 2                CONTROL_NUMBER   378676.84
# 33            PER_CAPITA_INCOME   159846.83
# 19            MEDIAN_HOME_VALUE    42021.80
# 13         LIFETIME_GIFT_AMOUNT     3549.90
# 20      MEDIAN_HOUSEHOLD_INCOME     2227.72
# 24          MONTHS_SINCE_ORIGIN     1770.96
# 21      MONTHS_SINCE_FIRST_GIFT     1740.78
# 14          LIFETIME_GIFT_COUNT     1465.68
# 18                LIFETIME_PROM      987.28
# 5                FILE_CARD_GIFT      868.61
# 10                LAST_GIFT_AMT      779.86
# 36          RECENT_AVG_GIFT_AMT      726.61
# 17        LIFETIME_MIN_GIFT_AMT      634.24
# 4                 FILE_AVG_GIFT      523.91
# 11        LIFETIME_AVG_GIFT_AMT      523.91
# 39        RECENT_RESPONSE_COUNT      441.97
# 37   RECENT_CARD_RESPONSE_COUNT      420.61
# 16        LIFETIME_MAX_GIFT_AMT      357.71
# 12           LIFETIME_CARD_PROM      326.96
# 6         FREQUENCY_STATUS_97NK      222.58
# 22       MONTHS_SINCE_LAST_GIFT      139.84
# 32                     PEP_STAR      106.63
# 25                 MOR_HIT_RATE       83.79
# 3                     DONOR_AGE       71.07
# 35     RECENT_AVG_CARD_GIFT_AMT       55.80
# 1                  CLUSTER_CODE       52.60
# 23  MONTHS_SINCE_LAST_PROM_RESP       51.71
# 26               NUMBER_PROM_12       51.68
# 31           PCT_OWNER_OCCUPIED       32.37
# 9                      IN_HOUSE       30.13
# 38    RECENT_CARD_RESPONSE_PROP       29.63
# 30               PCT_ATTRIBUTE4       19.02
# 40         RECENT_RESPONSE_PROP       18.53
# 8                  INCOME_GROUP       16.42
# 15          LIFETIME_GIFT_RANGE       15.42
# 29               PCT_ATTRIBUTE3       15.28
# 0                  CARD_PROM_12        8.75
# 28               PCT_ATTRIBUTE2        6.42
# 27               PCT_ATTRIBUTE1        6.06
# 7                    HOME_OWNER        0.57
# 41           RECENT_STAR_STATUS        0.29
# 34              PUBLISHED_PHONE        0.10

# %% [markdown]
# # Linear Support Vector Classification (L1)

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(features, labels)
model = SelectFromModel(lsvc,prefit=True)

# %%
from pandas import DataFrame
l1 = DataFrame(model.get_support(), columns = ["L1"], index=features.columns)
l1 = l1.reset_index()

# %%
l1[l1['L1'] == True]
# Out:
#                           index    L1
# 0                  CARD_PROM_12  True
# 1                  CLUSTER_CODE  True
# 3                     DONOR_AGE  True
# 4                 FILE_AVG_GIFT  True
# 6         FREQUENCY_STATUS_97NK  True
# 8                  INCOME_GROUP  True
# 9                      IN_HOUSE  True
# 10                LAST_GIFT_AMT  True
# 12           LIFETIME_CARD_PROM  True
# 13         LIFETIME_GIFT_AMOUNT  True
# 14          LIFETIME_GIFT_COUNT  True
# 16        LIFETIME_MAX_GIFT_AMT  True
# 17        LIFETIME_MIN_GIFT_AMT  True
# 18                LIFETIME_PROM  True
# 19            MEDIAN_HOME_VALUE  True
# 20      MEDIAN_HOUSEHOLD_INCOME  True
# 21      MONTHS_SINCE_FIRST_GIFT  True
# 22       MONTHS_SINCE_LAST_GIFT  True
# 23  MONTHS_SINCE_LAST_PROM_RESP  True
# 24          MONTHS_SINCE_ORIGIN  True
# 25                 MOR_HIT_RATE  True
# 26               NUMBER_PROM_12  True
# 28               PCT_ATTRIBUTE2  True
# 29               PCT_ATTRIBUTE3  True
# 30               PCT_ATTRIBUTE4  True
# 31           PCT_OWNER_OCCUPIED  True
# 32                     PEP_STAR  True
# 34              PUBLISHED_PHONE  True
# 35     RECENT_AVG_CARD_GIFT_AMT  True
# 36          RECENT_AVG_GIFT_AMT  True
# 37   RECENT_CARD_RESPONSE_COUNT  True
# 41           RECENT_STAR_STATUS  True

# %% [markdown]
# # We combine all these tests together

# %%
from functools import reduce
dfs = [IV, VI, Selected, FI, chi_sq, l1]
final_results = reduce(lambda left,right: pd.merge(left,right,on='index'), dfs)

# %% [markdown]
# # We vote each model

# %%
columns = ['IV', 'RF', 'Extratrees', 'Chi_Square']

score_table = pd.DataFrame({},[])
score_table['index'] = final_results['index']

for i in columns:
    score_table[i] = final_results['index'].isin(list(final_results.nlargest(5,i)['index'])).astype(int)
    
score_table['RFE'] = final_results['RFE'].astype(int)
score_table['L1'] = final_results['L1'].astype(int)

# %%
score_table['final_score'] = score_table.sum(axis=1)

# %%
score_table.sort_values('final_score',ascending=0)
# Out:
#                           index  IV  RF  Extratrees  Chi_Square  RFE  L1  \
# 0                  CARD_PROM_12   0   1           0           0    1   1
# 6         FREQUENCY_STATUS_97NK   1   0           0           0    1   1
# 20      MEDIAN_HOUSEHOLD_INCOME   0   0           1           1    0   1
# 12           LIFETIME_CARD_PROM   0   1           0           0    1   1
# 9                      IN_HOUSE   0   1           0           0    1   1
# 19            MEDIAN_HOME_VALUE   0   0           1           1    0   1
# 37   RECENT_CARD_RESPONSE_COUNT   1   0           0           0    1   1
# 36          RECENT_AVG_GIFT_AMT   0   0           0           0    1   1
# 34              PUBLISHED_PHONE   0   0           0           0    1   1
# 18                LIFETIME_PROM   0   0           0           0    1   1
# 29               PCT_ATTRIBUTE3   0   0           1           0    0   1
# 26               NUMBER_PROM_12   0   0           0           0    1   1
# 39        RECENT_RESPONSE_COUNT   1   0           0           0    1   0
# 23  MONTHS_SINCE_LAST_PROM_RESP   0   0           0           0    1   1
# 22       MONTHS_SINCE_LAST_GIFT   0   0           0           0    1   1
# 40         RECENT_RESPONSE_PROP   1   0           0           0    1   0
# 32                     PEP_STAR   0   0           0           0    1   1
# 21      MONTHS_SINCE_FIRST_GIFT   0   0           0           0    1   1
# 41           RECENT_STAR_STATUS   0   0           0           0    1   1
# 2                CONTROL_NUMBER   0   0           1           1    0   0
# 3                     DONOR_AGE   0   0           1           0    0   1
# 14          LIFETIME_GIFT_COUNT   0   0           0           0    1   1
# 13         LIFETIME_GIFT_AMOUNT   0   0           0           1    0   1
# 4                 FILE_AVG_GIFT   1   0           0           0    0   1
# 10                LAST_GIFT_AMT   0   1           0           0    0   1
# 8                  INCOME_GROUP   0   0           0           0    1   1
# 31           PCT_OWNER_OCCUPIED   0   0           0           0    0   1
# 38    RECENT_CARD_RESPONSE_PROP   0   0           0           0    1   0
# 35     RECENT_AVG_CARD_GIFT_AMT   0   0           0           0    0   1
# 7                    HOME_OWNER   0   0           0           0    1   0
# 33            PER_CAPITA_INCOME   0   0           0           1    0   0
# 17        LIFETIME_MIN_GIFT_AMT   0   0           0           0    0   1
# 16        LIFETIME_MAX_GIFT_AMT   0   0           0           0    0   1
# 28               PCT_ATTRIBUTE2   0   0           0           0    0   1
# 11        LIFETIME_AVG_GIFT_AMT   0   1           0           0    0   0
# 25                 MOR_HIT_RATE   0   0           0           0    0   1
# 24          MONTHS_SINCE_ORIGIN   0   0           0           0    0   1
# 1                  CLUSTER_CODE   0   0           0           0    0   1
# 30               PCT_ATTRIBUTE4   0   0           0           0    0   1
# 27               PCT_ATTRIBUTE1   0   0           0           0    0   0
# 5                FILE_CARD_GIFT   0   0           0           0    0   0
# 15          LIFETIME_GIFT_RANGE   0   0           0           0    0   0
#
#     final_score
# 0             3
# 6             3
# 20            3
# 12            3
# 9             3
# 19            3
# 37            3
# 36            2
# 34            2
# 18            2
# 29            2
# 26            2
# 39            2
# 23            2
# 22            2
# 40            2
# 32            2
# 21            2
# 41            2
# 2             2
# 3             2
# 14            2
# 13            2
# 4             2
# 10            2
# 8             2
# 31            1
# 38            1
# 35            1
# 7             1
# 33            1
# 17            1
# 16            1
# 28            1
# 11            1
# 25            1
# 24            1
# 1             1
# 30            1
# 27            0
# 5             0
# 15            0

# %% [markdown]
# In this section, we filiter our variables and selected variables that passed at least by one diagnoses test

# %%
features = features[list(score_table[score_table['final_score'] >= 1]['index'])]

# %% [markdown]
# To check for the perfect correlation among the variables, we plot the correlation graph using seaborn.The effect of perfect correlation means that your model may likely be overfitted. Therefore, it is better to reduce the number of the variables until all the terms can be uniquely
# estimated.

# %%
import seaborn as sns
# %matplotlib inline
sns.heatmap(features.corr())

# %%
features.corr()
# Out:
#                              CARD_PROM_12  CLUSTER_CODE  CONTROL_NUMBER  \
# CARD_PROM_12                         1.00          0.02           -0.14
# CLUSTER_CODE                         0.02          1.00           -0.10
# CONTROL_NUMBER                      -0.14         -0.10            1.00
# DONOR_AGE                            0.04          0.02           -0.01
# FILE_AVG_GIFT                       -0.03         -0.06            0.01
# FREQUENCY_STATUS_97NK                0.28          0.04           -0.02
# HOME_OWNER                           0.03         -0.12           -0.05
# INCOME_GROUP                        -0.01         -0.19            0.05
# IN_HOUSE                             0.21          0.03           -0.21
# LAST_GIFT_AMT                        0.02         -0.05            0.00
# LIFETIME_AVG_GIFT_AMT               -0.03         -0.06            0.01
# LIFETIME_CARD_PROM                   0.41          0.06           -0.12
# LIFETIME_GIFT_AMOUNT                 0.27          0.03           -0.11
# LIFETIME_GIFT_COUNT                  0.24          0.08           -0.13
# LIFETIME_MAX_GIFT_AMT                0.07         -0.02           -0.01
# LIFETIME_MIN_GIFT_AMT               -0.16         -0.06            0.04
# LIFETIME_PROM                        0.41          0.06           -0.21
# MEDIAN_HOME_VALUE                    0.02         -0.34            0.26
# MEDIAN_HOUSEHOLD_INCOME              0.01         -0.37            0.10
# MONTHS_SINCE_FIRST_GIFT              0.14          0.06           -0.09
# MONTHS_SINCE_LAST_GIFT              -0.32         -0.03            0.05
# MONTHS_SINCE_LAST_PROM_RESP         -0.14         -0.02           -0.00
# MONTHS_SINCE_ORIGIN                  0.13          0.06           -0.08
# MOR_HIT_RATE                         0.03         -0.05           -0.01
# NUMBER_PROM_12                       0.64          0.03           -0.32
# PCT_ATTRIBUTE2                      -0.01         -0.11            0.02
# PCT_ATTRIBUTE3                      -0.01         -0.13            0.05
# PCT_ATTRIBUTE4                      -0.01         -0.02           -0.02
# PCT_OWNER_OCCUPIED                   0.01          0.07           -0.10
# PEP_STAR                             0.20          0.06           -0.07
# PER_CAPITA_INCOME                    0.02         -0.37            0.08
# PUBLISHED_PHONE                     -0.00         -0.04           -0.11
# RECENT_AVG_CARD_GIFT_AMT             0.08         -0.03            0.01
# RECENT_AVG_GIFT_AMT                  0.02         -0.05            0.02
# RECENT_CARD_RESPONSE_COUNT           0.27          0.03           -0.04
# RECENT_CARD_RESPONSE_PROP            0.02          0.01            0.02
# RECENT_RESPONSE_COUNT                0.35          0.05           -0.05
# RECENT_RESPONSE_PROP                 0.10          0.03            0.00
# RECENT_STAR_STATUS                   0.03          0.04           -0.03
#
#                              DONOR_AGE  FILE_AVG_GIFT  FREQUENCY_STATUS_97NK  \
# CARD_PROM_12                      0.04          -0.03                   0.28
# CLUSTER_CODE                      0.02          -0.06                   0.04
# CONTROL_NUMBER                   -0.01           0.01                  -0.02
# DONOR_AGE                         1.00          -0.06                   0.04
# FILE_AVG_GIFT                    -0.06           1.00                  -0.35
# FREQUENCY_STATUS_97NK             0.04          -0.35                   1.00
# HOME_OWNER                       -0.02           0.01                  -0.03
# INCOME_GROUP                     -0.17           0.10                  -0.08
# IN_HOUSE                          0.10           0.05                   0.01
# LAST_GIFT_AMT                    -0.04           0.80                  -0.36
# LIFETIME_AVG_GIFT_AMT            -0.06           1.00                  -0.35
# LIFETIME_CARD_PROM                0.19          -0.23                   0.13
# LIFETIME_GIFT_AMOUNT              0.11           0.24                   0.08
# LIFETIME_GIFT_COUNT               0.17          -0.31                   0.35
# LIFETIME_MAX_GIFT_AMT            -0.02           0.73                  -0.22
# LIFETIME_MIN_GIFT_AMT            -0.09           0.80                  -0.31
# LIFETIME_PROM                     0.19          -0.18                   0.11
# MEDIAN_HOME_VALUE                -0.00           0.12                  -0.06
# MEDIAN_HOUSEHOLD_INCOME          -0.05           0.10                  -0.05
# MONTHS_SINCE_FIRST_GIFT           0.20          -0.26                   0.06
# MONTHS_SINCE_LAST_GIFT           -0.07           0.06                  -0.29
# MONTHS_SINCE_LAST_PROM_RESP      -0.02           0.11                  -0.34
# MONTHS_SINCE_ORIGIN               0.20          -0.26                   0.06
# MOR_HIT_RATE                      0.10          -0.01                  -0.00
# NUMBER_PROM_12                    0.08           0.07                   0.14
# PCT_ATTRIBUTE2                    0.08          -0.02                   0.01
# PCT_ATTRIBUTE3                   -0.10           0.02                  -0.01
# PCT_ATTRIBUTE4                    0.13          -0.02                  -0.00
# PCT_OWNER_OCCUPIED               -0.01          -0.01                   0.01
# PEP_STAR                          0.12          -0.31                   0.33
# PER_CAPITA_INCOME                 0.01           0.12                  -0.05
# PUBLISHED_PHONE                   0.06          -0.04                  -0.00
# RECENT_AVG_CARD_GIFT_AMT         -0.02           0.54                  -0.11
# RECENT_AVG_GIFT_AMT              -0.03           0.79                  -0.38
# RECENT_CARD_RESPONSE_COUNT        0.03          -0.26                   0.63
# RECENT_CARD_RESPONSE_PROP        -0.02          -0.14                   0.49
# RECENT_RESPONSE_COUNT             0.05          -0.34                   0.77
# RECENT_RESPONSE_PROP              0.02          -0.25                   0.71
# RECENT_STAR_STATUS                0.07          -0.08                  -0.14
#
#                              HOME_OWNER  INCOME_GROUP  IN_HOUSE  \
# CARD_PROM_12                       0.03         -0.01      0.21
# CLUSTER_CODE                      -0.12         -0.19      0.03
# CONTROL_NUMBER                    -0.05          0.05     -0.21
# DONOR_AGE                         -0.02         -0.17      0.10
# FILE_AVG_GIFT                      0.01          0.10      0.05
# FREQUENCY_STATUS_97NK             -0.03         -0.08      0.01
# HOME_OWNER                         1.00          0.27     -0.03
# INCOME_GROUP                       0.27          1.00     -0.03
# IN_HOUSE                          -0.03         -0.03      1.00
# LAST_GIFT_AMT                      0.01          0.08      0.05
# LIFETIME_AVG_GIFT_AMT              0.01          0.10      0.05
# LIFETIME_CARD_PROM                 0.02         -0.06      0.21
# LIFETIME_GIFT_AMOUNT              -0.02         -0.02      0.32
# LIFETIME_GIFT_COUNT               -0.03         -0.10      0.26
# LIFETIME_MAX_GIFT_AMT             -0.00          0.06      0.12
# LIFETIME_MIN_GIFT_AMT              0.01          0.08     -0.05
# LIFETIME_PROM                      0.01         -0.06      0.38
# MEDIAN_HOME_VALUE                  0.06          0.28      0.04
# MEDIAN_HOUSEHOLD_INCOME            0.15          0.37      0.02
# MONTHS_SINCE_FIRST_GIFT            0.01         -0.07      0.17
# MONTHS_SINCE_LAST_GIFT             0.02          0.04     -0.32
# MONTHS_SINCE_LAST_PROM_RESP       -0.00          0.03      0.01
# MONTHS_SINCE_ORIGIN                0.01         -0.07      0.16
# MOR_HIT_RATE                       0.16         -0.00      0.10
# NUMBER_PROM_12                     0.00         -0.02      0.58
# PCT_ATTRIBUTE2                     0.09         -0.00     -0.04
# PCT_ATTRIBUTE3                     0.07          0.09     -0.06
# PCT_ATTRIBUTE4                     0.01         -0.07     -0.00
# PCT_OWNER_OCCUPIED                 0.15          0.15     -0.02
# PEP_STAR                          -0.01         -0.08      0.11
# PER_CAPITA_INCOME                  0.08          0.31      0.04
# PUBLISHED_PHONE                    0.23         -0.02      0.01
# RECENT_AVG_CARD_GIFT_AMT           0.01          0.06      0.06
# RECENT_AVG_GIFT_AMT                0.01          0.08      0.06
# RECENT_CARD_RESPONSE_COUNT        -0.02         -0.04      0.05
# RECENT_CARD_RESPONSE_PROP         -0.04         -0.03     -0.01
# RECENT_RESPONSE_COUNT             -0.02         -0.07      0.05
# RECENT_RESPONSE_PROP              -0.06         -0.07      0.00
# RECENT_STAR_STATUS                -0.00         -0.03      0.07
#
#                              LAST_GIFT_AMT         ...          PEP_STAR  \
# CARD_PROM_12                          0.02         ...              0.20
# CLUSTER_CODE                         -0.05         ...              0.06
# CONTROL_NUMBER                        0.00         ...             -0.07
# DONOR_AGE                            -0.04         ...              0.12
# FILE_AVG_GIFT                         0.80         ...             -0.31
# FREQUENCY_STATUS_97NK                -0.36         ...              0.33
# HOME_OWNER                            0.01         ...             -0.01
# INCOME_GROUP                          0.08         ...             -0.08
# IN_HOUSE                              0.05         ...              0.11
# LAST_GIFT_AMT                         1.00         ...             -0.21
# LIFETIME_AVG_GIFT_AMT                 0.80         ...             -0.31
# LIFETIME_CARD_PROM                   -0.07         ...              0.59
# LIFETIME_GIFT_AMOUNT                  0.28         ...              0.39
# LIFETIME_GIFT_COUNT                  -0.22         ...              0.62
# LIFETIME_MAX_GIFT_AMT                 0.73         ...             -0.10
# LIFETIME_MIN_GIFT_AMT                 0.53         ...             -0.38
# LIFETIME_PROM                        -0.04         ...              0.56
# MEDIAN_HOME_VALUE                     0.11         ...             -0.06
# MEDIAN_HOUSEHOLD_INCOME               0.09         ...             -0.05
# MONTHS_SINCE_FIRST_GIFT              -0.10         ...              0.54
# MONTHS_SINCE_LAST_GIFT                0.09         ...             -0.11
# MONTHS_SINCE_LAST_PROM_RESP           0.12         ...             -0.07
# MONTHS_SINCE_ORIGIN                  -0.10         ...              0.53
# MOR_HIT_RATE                          0.00         ...              0.03
# NUMBER_PROM_12                        0.07         ...              0.17
# PCT_ATTRIBUTE2                       -0.01         ...              0.02
# PCT_ATTRIBUTE3                        0.00         ...             -0.02
# PCT_ATTRIBUTE4                       -0.01         ...              0.03
# PCT_OWNER_OCCUPIED                   -0.00         ...              0.03
# PEP_STAR                             -0.21         ...              1.00
# PER_CAPITA_INCOME                     0.11         ...             -0.05
# PUBLISHED_PHONE                      -0.03         ...              0.03
# RECENT_AVG_CARD_GIFT_AMT              0.49         ...             -0.09
# RECENT_AVG_GIFT_AMT                   0.80         ...             -0.22
# RECENT_CARD_RESPONSE_COUNT           -0.26         ...              0.40
# RECENT_CARD_RESPONSE_PROP            -0.22         ...              0.17
# RECENT_RESPONSE_COUNT                -0.31         ...              0.45
# RECENT_RESPONSE_PROP                 -0.30         ...              0.26
# RECENT_STAR_STATUS                   -0.00         ...              0.36
#
#                              PER_CAPITA_INCOME  PUBLISHED_PHONE  \
# CARD_PROM_12                              0.02            -0.00
# CLUSTER_CODE                             -0.37            -0.04
# CONTROL_NUMBER                            0.08            -0.11
# DONOR_AGE                                 0.01             0.06
# FILE_AVG_GIFT                             0.12            -0.04
# FREQUENCY_STATUS_97NK                    -0.05            -0.00
# HOME_OWNER                                0.08             0.23
# INCOME_GROUP                              0.31            -0.02
# IN_HOUSE                                  0.04             0.01
# LAST_GIFT_AMT                             0.11            -0.03
# LIFETIME_AVG_GIFT_AMT                     0.12            -0.04
# LIFETIME_CARD_PROM                       -0.02             0.05
# LIFETIME_GIFT_AMOUNT                      0.03            -0.00
# LIFETIME_GIFT_COUNT                      -0.06             0.03
# LIFETIME_MAX_GIFT_AMT                     0.09            -0.03
# LIFETIME_MIN_GIFT_AMT                     0.08            -0.04
# LIFETIME_PROM                            -0.00             0.05
# MEDIAN_HOME_VALUE                         0.73            -0.08
# MEDIAN_HOUSEHOLD_INCOME                   0.81             0.02
# MONTHS_SINCE_FIRST_GIFT                  -0.03             0.07
# MONTHS_SINCE_LAST_GIFT                   -0.01             0.00
# MONTHS_SINCE_LAST_PROM_RESP               0.01             0.00
# MONTHS_SINCE_ORIGIN                      -0.03             0.07
# MOR_HIT_RATE                              0.05             0.21
# NUMBER_PROM_12                            0.03            -0.00
# PCT_ATTRIBUTE2                            0.11             0.08
# PCT_ATTRIBUTE3                           -0.04             0.03
# PCT_ATTRIBUTE4                            0.12             0.04
# PCT_OWNER_OCCUPIED                        0.21             0.07
# PEP_STAR                                 -0.05             0.03
# PER_CAPITA_INCOME                         1.00             0.02
# PUBLISHED_PHONE                           0.02             1.00
# RECENT_AVG_CARD_GIFT_AMT                  0.09            -0.02
# RECENT_AVG_GIFT_AMT                       0.11            -0.03
# RECENT_CARD_RESPONSE_COUNT               -0.02            -0.00
# RECENT_CARD_RESPONSE_PROP                -0.01            -0.02
# RECENT_RESPONSE_COUNT                    -0.06             0.00
# RECENT_RESPONSE_PROP                     -0.05            -0.02
# RECENT_STAR_STATUS                       -0.02             0.03
#
#                              RECENT_AVG_CARD_GIFT_AMT  RECENT_AVG_GIFT_AMT  \
# CARD_PROM_12                                     0.08                 0.02
# CLUSTER_CODE                                    -0.03                -0.05
# CONTROL_NUMBER                                   0.01                 0.02
# DONOR_AGE                                       -0.02                -0.03
# FILE_AVG_GIFT                                    0.54                 0.79
# FREQUENCY_STATUS_97NK                           -0.11                -0.38
# HOME_OWNER                                       0.01                 0.01
# INCOME_GROUP                                     0.06                 0.08
# IN_HOUSE                                         0.06                 0.06
# LAST_GIFT_AMT                                    0.49                 0.80
# LIFETIME_AVG_GIFT_AMT                            0.54                 0.79
# LIFETIME_CARD_PROM                              -0.04                -0.05
# LIFETIME_GIFT_AMOUNT                             0.29                 0.33
# LIFETIME_GIFT_COUNT                             -0.09                -0.22
# LIFETIME_MAX_GIFT_AMT                            0.49                 0.71
# LIFETIME_MIN_GIFT_AMT                            0.31                 0.48
# LIFETIME_PROM                                   -0.02                -0.02
# MEDIAN_HOME_VALUE                                0.08                 0.11
# MEDIAN_HOUSEHOLD_INCOME                          0.07                 0.10
# MONTHS_SINCE_FIRST_GIFT                         -0.10                -0.08
# MONTHS_SINCE_LAST_GIFT                           0.00                 0.07
# MONTHS_SINCE_LAST_PROM_RESP                      0.05                 0.15
# MONTHS_SINCE_ORIGIN                             -0.10                -0.08
# MOR_HIT_RATE                                     0.01                 0.00
# NUMBER_PROM_12                                   0.10                 0.08
# PCT_ATTRIBUTE2                                  -0.00                -0.01
# PCT_ATTRIBUTE3                                   0.01                 0.00
# PCT_ATTRIBUTE4                                  -0.02                -0.01
# PCT_OWNER_OCCUPIED                              -0.01                -0.00
# PEP_STAR                                        -0.09                -0.22
# PER_CAPITA_INCOME                                0.09                 0.11
# PUBLISHED_PHONE                                 -0.02                -0.03
# RECENT_AVG_CARD_GIFT_AMT                         1.00                 0.63
# RECENT_AVG_GIFT_AMT                              0.63                 1.00
# RECENT_CARD_RESPONSE_COUNT                       0.11                -0.28
# RECENT_CARD_RESPONSE_PROP                        0.21                -0.22
# RECENT_RESPONSE_COUNT                           -0.07                -0.34
# RECENT_RESPONSE_PROP                            -0.05                -0.31
# RECENT_STAR_STATUS                              -0.02                -0.00
#
#                              RECENT_CARD_RESPONSE_COUNT  \
# CARD_PROM_12                                       0.27
# CLUSTER_CODE                                       0.03
# CONTROL_NUMBER                                    -0.04
# DONOR_AGE                                          0.03
# FILE_AVG_GIFT                                     -0.26
# FREQUENCY_STATUS_97NK                              0.63
# HOME_OWNER                                        -0.02
# INCOME_GROUP                                      -0.04
# IN_HOUSE                                           0.05
# LAST_GIFT_AMT                                     -0.26
# LIFETIME_AVG_GIFT_AMT                             -0.26
# LIFETIME_CARD_PROM                                 0.22
# LIFETIME_GIFT_AMOUNT                               0.19
# LIFETIME_GIFT_COUNT                                0.45
# LIFETIME_MAX_GIFT_AMT                             -0.16
# LIFETIME_MIN_GIFT_AMT                             -0.24
# LIFETIME_PROM                                      0.20
# MEDIAN_HOME_VALUE                                 -0.03
# MEDIAN_HOUSEHOLD_INCOME                           -0.02
# MONTHS_SINCE_FIRST_GIFT                            0.10
# MONTHS_SINCE_LAST_GIFT                            -0.15
# MONTHS_SINCE_LAST_PROM_RESP                       -0.17
# MONTHS_SINCE_ORIGIN                                0.09
# MOR_HIT_RATE                                      -0.01
# NUMBER_PROM_12                                     0.16
# PCT_ATTRIBUTE2                                     0.01
# PCT_ATTRIBUTE3                                    -0.01
# PCT_ATTRIBUTE4                                    -0.01
# PCT_OWNER_OCCUPIED                                 0.01
# PEP_STAR                                           0.40
# PER_CAPITA_INCOME                                 -0.02
# PUBLISHED_PHONE                                   -0.00
# RECENT_AVG_CARD_GIFT_AMT                           0.11
# RECENT_AVG_GIFT_AMT                               -0.28
# RECENT_CARD_RESPONSE_COUNT                         1.00
# RECENT_CARD_RESPONSE_PROP                          0.79
# RECENT_RESPONSE_COUNT                              0.84
# RECENT_RESPONSE_PROP                               0.72
# RECENT_STAR_STATUS                                -0.03
#
#                              RECENT_CARD_RESPONSE_PROP  RECENT_RESPONSE_COUNT  \
# CARD_PROM_12                                      0.02                   0.35
# CLUSTER_CODE                                      0.01                   0.05
# CONTROL_NUMBER                                    0.02                  -0.05
# DONOR_AGE                                        -0.02                   0.05
# FILE_AVG_GIFT                                    -0.14                  -0.34
# FREQUENCY_STATUS_97NK                             0.49                   0.77
# HOME_OWNER                                       -0.04                  -0.02
# INCOME_GROUP                                     -0.03                  -0.07
# IN_HOUSE                                         -0.01                   0.05
# LAST_GIFT_AMT                                    -0.22                  -0.31
# LIFETIME_AVG_GIFT_AMT                            -0.14                  -0.34
# LIFETIME_CARD_PROM                               -0.17                   0.32
# LIFETIME_GIFT_AMOUNT                             -0.04                   0.24
# LIFETIME_GIFT_COUNT                               0.15                   0.54
# LIFETIME_MAX_GIFT_AMT                            -0.16                  -0.19
# LIFETIME_MIN_GIFT_AMT                            -0.00                  -0.34
# LIFETIME_PROM                                    -0.17                   0.28
# MEDIAN_HOME_VALUE                                -0.01                  -0.06
# MEDIAN_HOUSEHOLD_INCOME                          -0.02                  -0.05
# MONTHS_SINCE_FIRST_GIFT                          -0.20                   0.18
# MONTHS_SINCE_LAST_GIFT                           -0.19                  -0.22
# MONTHS_SINCE_LAST_PROM_RESP                      -0.25                  -0.26
# MONTHS_SINCE_ORIGIN                              -0.20                   0.17
# MOR_HIT_RATE                                     -0.02                  -0.01
# NUMBER_PROM_12                                    0.01                   0.20
# PCT_ATTRIBUTE2                                    0.00                   0.01
# PCT_ATTRIBUTE3                                   -0.00                  -0.01
# PCT_ATTRIBUTE4                                   -0.02                  -0.00
# PCT_OWNER_OCCUPIED                               -0.01                   0.01
# PEP_STAR                                          0.17                   0.45
# PER_CAPITA_INCOME                                -0.01                  -0.06
# PUBLISHED_PHONE                                  -0.02                   0.00
# RECENT_AVG_CARD_GIFT_AMT                          0.21                  -0.07
# RECENT_AVG_GIFT_AMT                              -0.22                  -0.34
# RECENT_CARD_RESPONSE_COUNT                        0.79                   0.84
# RECENT_CARD_RESPONSE_PROP                         1.00                   0.54
# RECENT_RESPONSE_COUNT                             0.54                   1.00
# RECENT_RESPONSE_PROP                              0.75                   0.81
# RECENT_STAR_STATUS                               -0.11                  -0.04
#
#                              RECENT_RESPONSE_PROP  RECENT_STAR_STATUS
# CARD_PROM_12                                 0.10                0.03
# CLUSTER_CODE                                 0.03                0.04
# CONTROL_NUMBER                               0.00               -0.03
# DONOR_AGE                                    0.02                0.07
# FILE_AVG_GIFT                               -0.25               -0.08
# FREQUENCY_STATUS_97NK                        0.71               -0.14
# HOME_OWNER                                  -0.06               -0.00
# INCOME_GROUP                                -0.07               -0.03
# IN_HOUSE                                     0.00                0.07
# LAST_GIFT_AMT                               -0.30               -0.00
# LIFETIME_AVG_GIFT_AMT                       -0.25               -0.08
# LIFETIME_CARD_PROM                          -0.06                0.34
# LIFETIME_GIFT_AMOUNT                         0.04                0.26
# LIFETIME_GIFT_COUNT                          0.30                0.30
# LIFETIME_MAX_GIFT_AMT                       -0.21                0.02
# LIFETIME_MIN_GIFT_AMT                       -0.14               -0.14
# LIFETIME_PROM                               -0.07                0.33
# MEDIAN_HOME_VALUE                           -0.05               -0.03
# MEDIAN_HOUSEHOLD_INCOME                     -0.05               -0.02
# MONTHS_SINCE_FIRST_GIFT                     -0.10                0.32
# MONTHS_SINCE_LAST_GIFT                      -0.28                0.02
# MONTHS_SINCE_LAST_PROM_RESP                 -0.37                0.06
# MONTHS_SINCE_ORIGIN                         -0.10                0.32
# MOR_HIT_RATE                                -0.02                0.02
# NUMBER_PROM_12                               0.04                0.07
# PCT_ATTRIBUTE2                               0.01                0.01
# PCT_ATTRIBUTE3                              -0.01               -0.02
# PCT_ATTRIBUTE4                              -0.01                0.02
# PCT_OWNER_OCCUPIED                          -0.01                0.02
# PEP_STAR                                     0.26                0.36
# PER_CAPITA_INCOME                           -0.05               -0.02
# PUBLISHED_PHONE                             -0.02                0.03
# RECENT_AVG_CARD_GIFT_AMT                    -0.05               -0.02
# RECENT_AVG_GIFT_AMT                         -0.31               -0.00
# RECENT_CARD_RESPONSE_COUNT                   0.72               -0.03
# RECENT_CARD_RESPONSE_PROP                    0.75               -0.11
# RECENT_RESPONSE_COUNT                        0.81               -0.04
# RECENT_RESPONSE_PROP                         1.00               -0.12
# RECENT_STAR_STATUS                          -0.12                1.00
#
# [39 rows x 39 columns]

# %% [markdown]
# From the above table and the seaborn graph, we noticed that the following variables appeared to be perfectly correlated 'LAST_GIFT_AMT','FILE_AVG_GIFT', RECENT_RESPONSE_COUNT', 'LIFETIME_MAX_GIFT_AMT', 'LIFETIME_GIFT_AMOUNT', 'PER_CAPITA_INCOME', 'MEDIAN_HOUSEHOLD_INCOME' and etc. Therefore, we test for multicollinearity.

# %% [markdown]
# # Multicollinearity test using Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calculate_vif(features):
    vif = pd.DataFrame()
    vif["Features"] = features.columns
    vif["VIF"] = [variance_inflation_factor(features.values, i) for i in range(features.shape[1])]    
    return(vif)

# %%
vif = calculate_vif(features)
while vif['VIF'][vif['VIF'] > 5].any():
    remove = vif.sort_values('VIF',ascending=0)['Features'][:1]
    features.drop(remove,axis=1,inplace=True)
    vif = calculate_vif(features)
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:167: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %% [markdown]
# Below are the list of the variables that we can trust

# %%
list(vif['Features'])
# Out:
# ['CLUSTER_CODE',
#  'CONTROL_NUMBER',
#  'IN_HOUSE',
#  'LIFETIME_GIFT_AMOUNT',
#  'LIFETIME_MAX_GIFT_AMT',
#  'LIFETIME_MIN_GIFT_AMT',
#  'MEDIAN_HOME_VALUE',
#  'MOR_HIT_RATE',
#  'PCT_ATTRIBUTE3',
#  'PCT_ATTRIBUTE4',
#  'PEP_STAR',
#  'PUBLISHED_PHONE',
#  'RECENT_AVG_CARD_GIFT_AMT',
#  'RECENT_CARD_RESPONSE_PROP',
#  'RECENT_STAR_STATUS']

# %%
import seaborn as sns
# %matplotlib inline
sns.heatmap(features.corr())

# %%
features.describe()
# Out:
#        CLUSTER_CODE  CONTROL_NUMBER  IN_HOUSE  LIFETIME_GIFT_AMOUNT  \
# count      19372.00        19372.00  19372.00              19372.00
# mean          24.95        96546.23      0.07                104.43
# std           15.24        55830.64      0.26                105.72
# min            0.00            5.00      0.00                 15.00
# 25%           12.00        48289.00      0.00                 42.00
# 50%           25.00        96937.00      0.00                 79.00
# 75%           37.00       145429.50      0.00                132.00
# max           53.00       191779.00      1.00               3775.00
#
#        LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  MEDIAN_HOME_VALUE  \
# count               19372.00               19372.00           19372.00
# mean                   19.21                   7.62            1079.87
# std                    16.10                   7.96             960.75
# min                     5.00                   0.00               0.00
# 25%                    12.00                   3.00             518.00
# 50%                    16.00                   5.00             747.00
# 75%                    21.00                  10.00            1227.00
# max                  1000.00                 450.00            6000.00
#
#        MOR_HIT_RATE  PCT_ATTRIBUTE3  PCT_ATTRIBUTE4  PEP_STAR  \
# count      19372.00        19372.00        19372.00  19372.00
# mean           3.36           29.60           32.85      0.50
# std            9.50           15.12           17.84      0.50
# min            0.00            0.00            0.00      0.00
# 25%            0.00           20.00           21.00      0.00
# 50%            0.00           29.00           32.00      1.00
# 75%            3.00           39.00           43.00      1.00
# max          241.00           99.00           99.00      1.00
#
#        PUBLISHED_PHONE  RECENT_AVG_CARD_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# count         19372.00                  19372.00                   19372.00
# mean              0.50                     11.69                       0.23
# std               0.50                     10.83                       0.19
# min               0.00                      0.00                       0.00
# 25%               0.00                      5.00                       0.10
# 50%               0.00                     10.14                       0.20
# 75%               1.00                     16.00                       0.33
# max               1.00                    300.00                       1.00
#
#        RECENT_STAR_STATUS
# count            19372.00
# mean                 0.93
# std                  2.55
# min                  0.00
# 25%                  0.00
# 50%                  0.00
# 75%                  1.00
# max                 22.00

# %% [markdown]
# # Step 6: Visualization of the variables

# %%
features.hist(figsize=(20,10))
plt.show()

# %% [markdown]
# # Step 7. Machine Learning Algorithm Training

# %%
# Split-out validation dataset
# Test options and evaluation metric
seed = 7
scoring = 'f1' # 'precision' 'recall' ' f1'

# here we convert the pandas dataframe into an array of figures
array = features.values

# Note : for array [rows , columns] 
# rows separated from column by comma

# features/ variables
X = array[:,1:] # : all rows , all columns from the seconds



# the percentage of the dataset in the test set
validation_size = 0.20



# Split-out validation dataset
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, labels, test_size=validation_size, random_state=seed)

# we now have X_train and Y_train for preparing models
# and  X_validation and Y_validation we can use later.

# %%
# Spot Check Algorithms: a list of the models we are going to use
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
#models.append(('GPC',GaussianProcessClassifier()))
models.append(('NB', GaussianNB()))
#models.append(('SVM', SVC()))
models.append(('RF', RandomForestClassifier()))
models.append(('NN',MLPClassifier()))

# %%
model
# Out:
# SelectFromModel(estimator=LinearSVC(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l1', random_state=None, tol=0.0001,
#      verbose=0),
#         norm_order=1, prefit=True, threshold=None)

# %%
# evaluate each model in turn
results = []
names = []
for name, model in models:
	kfold = model_selection.KFold(n_splits=10, random_state=seed)
	cv_results = model_selection.cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# Out:
# LR: 0.010181 (0.005112)
# LDA: 0.010615 (0.008638)
# KNN: 0.151597 (0.013423)
# CART: 0.284568 (0.017259)
# NB: 0.080937 (0.023307)
# RF: 0.134841 (0.020792)
# NN: 0.143287 (0.162733)

# %%
# Compare Algorithms
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

#You can see that the box and whisker plots are squashed at the top of the range, with many samples achieving 100% accuracy.

# %% [raw]
# Fron the above graph, we observed that the DecisionTreeClassifier (CART) outperformed other predition models because the model has the highest mean when compared with other selected models.

# %%
# We list the 10 most important variables in our dataset 

from sklearn.feature_selection import RFE

# Create the RFE object and rank each pixel
rf =RandomForestClassifier()
rfe = RFE(estimator=rf, n_features_to_select=10, step=1)
rfe.fit(X_train, Y_train)

# Here we list the n most important features
from itertools import compress
l = features.columns.values[1:]
b = rfe.get_support(indices=False)
print(list(compress(l, b)))
# Out:
# ['CONTROL_NUMBER', 'LIFETIME_GIFT_AMOUNT', 'LIFETIME_MAX_GIFT_AMT', 'LIFETIME_MIN_GIFT_AMT', 'MEDIAN_HOME_VALUE', 'MOR_HIT_RATE', 'PCT_ATTRIBUTE3', 'PCT_ATTRIBUTE4', 'RECENT_AVG_CARD_GIFT_AMT', 'RECENT_CARD_RESPONSE_PROP']

# %%
# create a new model
cart = DecisionTreeClassifier()

cart.fit(X_train[:,b], Y_train)

# Here the final countdown
# here we apply the model on the testing test we separated earlier on
predictions = cart.predict(X_validation[:,b])

print('F1 Score')
print(f1_score(Y_validation, predictions),'\n')

TN, FP, FN, TP = confusion_matrix(Y_validation, predictions).ravel()
print('Confusion Matrix')
print(confusion_matrix(Y_validation, predictions),'\n')

print ('True positives',TP)
print ('False positives',FP)
print ('True negatives',TN)
print ('False negatives',FN,'\n')

print('Classification Report')
print(classification_report(Y_validation, predictions),'\n')
# Out:
# F1 Score
# 0.28118811881188116
#
# Confusion Matrix
# [[2139  763]
#  [ 689  284]]
#
# True positives 284
# False positives 763
# True negatives 2139
# False negatives 689
#
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.76      0.74      0.75      2902
#           1       0.27      0.29      0.28       973
#
# avg / total       0.63      0.63      0.63      3875

# %%
 
Accuracy = (TP + TN)/(TN+FN+TP+FP)
Accuracy
# Out:
# 0.6273548387096775

# %% [markdown]
# # Deployment of the model

# %%
mail_cost = 2

avg_gift = 15
print('If the charity orgnisation decided to mail only household that may likely donate')
print('The charity will spend the cost of £', (tp+fn)*mail_cost, 
      'and earn £', tp*avg_gift, 
      ', to make the profit of £',tp*avg_gift-(tp+fn)*mail_cost)

print()
print('If the charity mails every one')
print('The charity spends £', (tp+fp+tn+fn)*mail_cost, 
      'and earns £',(tp+fn)*avg_gift, 
      ',making profit of £',(tp+fn)*avg_gift-(tp+fp+tn+fn)*mail_cost)
# Out:
# If the charity orgnisation decided to mail only household that may likely donate
# The charity will spend the cost of £ 1946 and earn £ 4185 , to make the profit of £ 2239
#
# If the charity mails every one
# The charity spends £ 7750 and earns £ 14595 ,making profit of £ 6845
